# %% [markdown]
# ## Imported library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('Usa real estate Dataset.csv')

# %% [markdown]
# ## view the first few rows

# %%
df.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# 2  Juana Diaz  Puerto Rico     795.0       748.0            NaN
# 3       Ponce  Puerto Rico     731.0      1800.0            NaN
# 4    Mayaguez  Puerto Rico     680.0         NaN            NaN

# %% [markdown]
# ## view the last few rows

# %%
df.tail()
# Out:
#          brokered_by status     price  bed  bath  acre_lot     street  \
# 2226377      23009.0   sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0   sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0   sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0   sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0   sold  580000.0  5.0   3.0      0.31   307704.0
#
#              city       state  zip_code  house_size prev_sold_date
# 2226377  Richland  Washington   99354.0      3600.0     2022-03-25
# 2226378  Richland  Washington   99354.0      1616.0     2022-03-25
# 2226379  Richland  Washington   99354.0      3200.0     2022-03-24
# 2226380  Richland  Washington   99354.0       933.0     2022-03-24
# 2226381  Richland  Washington   99354.0      3615.0     2022-03-23

# %% [markdown]
# ## Shape of Dataset

# %%
df.shape
# Out:
# (2226382, 12)

# %% [markdown]
# ## Size of Dataset

# %%
df.size
# Out:
# 26716584

# %% [markdown]
# ## column of dataset

# %%
df.columns
# Out:
# Index(['brokered_by', 'status', 'price', 'bed', 'bath', 'acre_lot', 'street',
#        'city', 'state', 'zip_code', 'house_size', 'prev_sold_date'],
#       dtype='object')

# %% [markdown]
# ## Dataset Checking data types

# %%
df.dtypes
# Out:
# brokered_by       float64
# status             object
# price             float64
# bed               float64
# bath              float64
# acre_lot          float64
# street            float64
# city               object
# state              object
# zip_code          float64
# house_size        float64
# prev_sold_date     object
# dtype: object

# %% [markdown]
# ## Data information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %% [markdown]
# ## Label Encoading

# %%
le=LabelEncoder()
df['status']=le.fit_transform(df['status'])

# %%
le=LabelEncoder()
df['city']=le.fit_transform(df['city'])

# %%
le=LabelEncoder()
df['state']=le.fit_transform(df['state'])

# %%
le=LabelEncoder()
df['prev_sold_date']=le.fit_transform(df['prev_sold_date'])

# %% [markdown]
# ## After label encoading check Data  information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          int32
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            int32
#  8   state           int32
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  int32
# dtypes: float64(8), int32(4)
# memory usage: 169.9 MB

# %% [markdown]
# ## Stastical Summarization of data

# %%
df.describe()
# Out:
#         brokered_by        status         price           bed          bath  \
# count  2.221849e+06  2.226382e+06  2.224841e+06  1.745065e+06  1.714611e+06
# mean   5.293989e+04  7.407017e-01  5.241955e+05  3.275841e+00  2.496440e+00
# std    3.064275e+04  9.599509e-01  2.138893e+06  1.567274e+00  1.652573e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.386100e+04  0.000000e+00  1.650000e+05  3.000000e+00  2.000000e+00
# 50%    5.288400e+04  0.000000e+00  3.250000e+05  3.000000e+00  2.000000e+00
# 75%    7.918300e+04  2.000000e+00  5.500000e+05  4.000000e+00  3.000000e+00
# max    1.101420e+05  2.000000e+00  2.147484e+09  4.730000e+02  8.300000e+02
#
#            acre_lot        street          city         state      zip_code  \
# count  1.900793e+06  2.215516e+06  2.226382e+06  2.226382e+06  2.226083e+06
# mean   1.522303e+01  1.012325e+06  1.005351e+04  2.506315e+01  5.218668e+04
# ...

# %% [markdown]
# ## Checking Null Values

# %%
df.isna()
# Out:
#          brokered_by  status  price    bed   bath  acre_lot  street   city  \
# 0              False   False  False  False  False     False   False  False
# 1              False   False  False  False  False     False   False  False
# 2              False   False  False  False  False     False   False  False
# 3              False   False  False  False  False     False   False  False
# 4              False   False  False  False  False     False   False  False
# ...              ...     ...    ...    ...    ...       ...     ...    ...
# 2226377        False   False  False  False  False     False   False  False
# 2226378        False   False  False  False  False     False   False  False
# 2226379        False   False  False  False  False     False   False  False
# 2226380        False   False  False  False  False     False   False  False
# 2226381        False   False  False  False  False     False   False  False
#
#          state  zip_code  house_size  prev_sold_date
# ...

# %% [markdown]
# ## Checking null values of sum

# %%
df.isna().sum()
# Out:
# brokered_by         4533
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# street             10866
# city                   0
# state                  0
# zip_code             299
# house_size        568484
# prev_sold_date         0
# dtype: int64

# %% [markdown]
# ## Treating Null values using Filna Method

# %%
df['brokered_by'].fillna(df['brokered_by'].mode()[0],inplace=True)

# %%
df['brokered_by'].isna().sum()
# Out:
# 0

# %%
df['brokered_by'].value_counts()
# Out:
# brokered_by
# 22611.0    50191
# 16829.0    27732
# 53016.0    21709
# 23592.0     9176
# 30807.0     8464
#            ...
# 36774.0        1
# 88410.0        1
# 92528.0        1
# 76894.0        1
# 98730.0        1
# Name: count, Length: 110143, dtype: int64

# %%
df['price'].fillna(df['price'].median(),inplace=True)

# %%
df['price'].isna().sum()
# Out:
# 0

# %%
df['price'].value_counts()
# Out:
# price
# 325000.0    15581
# 350000.0    15430
# 250000.0    15254
# 225000.0    13939
# 450000.0    13213
#             ...
# 344725.0        1
# 345295.0        1
# 300355.0        1
# 305275.0        1
# 280290.0        1
# Name: count, Length: 102137, dtype: int64

# %%
df['bed'].fillna(df['bed'].median(),inplace=True)

# %%
df['bed'].isna().sum()
# Out:
# 0

# %%
df['bed'].value_counts()
# Out:
# bed
# 3.0      1235240
# 4.0       440566
# 2.0       311019
# 5.0       120637
# 1.0        65098
#           ...
# 110.0          1
# 82.0           1
# 69.0           1
# 102.0          1
# 120.0          1
# Name: count, Length: 99, dtype: int64

# %%
df['bath'].fillna(df['bath'].median(),inplace=True)

# %%
df['bath'].isna().sum()
# Out:
# 0

# %%
df['bath'].value_counts()
# Out:
# bath
# 2.0      1258065
# 3.0       471821
# 1.0       260131
# 4.0       157290
# 5.0        45563
#           ...
# 460.0          1
# 163.0          1
# 752.0          1
# 80.0           1
# 55.0           1
# Name: count, Length: 86, dtype: int64

# %%
df['acre_lot'].fillna(df['acre_lot'].median(),inplace=True)

# %%
df['acre_lot'].isna().sum()
# Out:
# 0

# %%
df['acre_lot'].value_counts()
# Out:
# acre_lot
# 0.26       352218
# 0.17        66180
# 0.14        65258
# 0.16        55864
# 0.23        55742
#             ...
# 99.18           1
# 273.50          1
# 2190.80         1
# 415.65          1
# 1650.72         1
# Name: count, Length: 16057, dtype: int64

# %%
df['street'].fillna(df['street'].mode()[0],inplace=True)

# %%
df['street'].isna().sum()
# Out:
# 0

# %%
df['street'].value_counts()
# Out:
# street
# 1916862.0    11024
# 1861860.0      142
# 1951128.0      127
# 1801524.0       98
# 793078.0        87
#              ...
# 973748.0         1
# 228022.0         1
# 1057744.0        1
# 1982508.0        1
# 307704.0         1
# Name: count, Length: 2001358, dtype: int64

# %%
df['city'].fillna(df['city'].mode()[0],inplace=True)

# %%
df['city'].isna().sum()
# Out:
# 0

# %%
df['city'].value_counts()
# Out:
# city
# 8216     23862
# 3167     18238
# 12444    12634
# 8621     11743
# 13948    10449
#          ...
# 413          1
# 3579         1
# 10087        1
# 18105        1
# 8820         1
# Name: count, Length: 20099, dtype: int64

# %%
df['state'].fillna(df['state'].mode()[0],inplace=True)

# %%
df['state'].isna().sum()
# Out:
# 0

# %%
df['state'].value_counts()
# Out:
# state
# 9     249432
# 4     227215
# 46    208335
# 34    103159
# 35     85745
# 14     85280
# 10     80977
# 40     78373
# 2      72825
# 50     68763
# 51     62461
# 37     59207
# 32     48199
# 21     46052
# 26     45145
# 24     43412
# 23     42429
# 53     42390
# 43     42367
# 45     40964
# 22     38041
# 38     37140
# 0      34053
# 5      32293
# 39     32163
# 18     26316
# 19     25815
# 3      23045
# 16     23033
# 33     21074
# 15     18840
# 13     16760
# 25     16255
# 17     14858
# 29     14667
# 47     14557
# 6      14008
# 52     12309
# 27     10059
# 7       8628
# 42      8157
# 12      7243
# 8       6625
# 28      6309
# 20      5065
# 44      4690
# 36      4268
# 54      4039
# 31      3642
# 41      3126
# 48      2600
# 1       2581
# 49       895
# 11       489
# 55         8
# 30         1
# Name: count, dtype: int64

# %%
df['zip_code'].fillna(df['zip_code'].median(),inplace=True)

# %%
df['zip_code'].isna().sum()
# Out:
# 0

# %%
df['zip_code'].value_counts()
# Out:
# zip_code
# 33993.0    2472
# 33981.0    2282
# 33974.0    1996
# 33160.0    1718
# 32909.0    1707
#            ...
# 51441.0       1
# 50848.0       1
# 52047.0       1
# 50668.0       1
# 99335.0       1
# Name: count, Length: 30334, dtype: int64

# %%
df['house_size'].fillna(df['house_size'].mode()[0],inplace=True)

# %%
df['house_size'].isna().sum()
# Out:
# 0

# %%
df['house_size'].value_counts()
# Out:
# house_size
# 1200.0     577422
# 1500.0       6316
# 1800.0       6272
# 1400.0       6108
# 1600.0       5630
#             ...
# 9191.0          1
# 16110.0         1
# 10538.0         1
# 8231.0          1
# 21402.0         1
# Name: count, Length: 12061, dtype: int64

# %%
df['prev_sold_date'] = pd.to_datetime(df['prev_sold_date'], errors='coerce')

# %%
df['prev_sold_date'].fillna(df['prev_sold_date'].min(), inplace=True)

# %%
df['prev_sold_date'].isna().sum()
# Out:
# 0

# %%
df['prev_sold_date'].value_counts()
# Out:
# prev_sold_date
# 1970-01-01 00:00:00.000014954    734297
# 1970-01-01 00:00:00.000014586     17171
# 1970-01-01 00:00:00.000014601     16297
# 1970-01-01 00:00:00.000014608     15762
# 1970-01-01 00:00:00.000014594     15038
#                                   ...
# 1970-01-01 00:00:00.000011835         1
# 1970-01-01 00:00:00.000011930         1
# 1970-01-01 00:00:00.000006440         1
# 1970-01-01 00:00:00.000011908         1
# 1970-01-01 00:00:00.000008149         1
# Name: count, Length: 14955, dtype: int64

# %% [markdown]
# ## All null values now filled

# %%
df.isnull().sum()
# Out:
# brokered_by       0
# status            0
# price             0
# bed               0
# bath              0
# acre_lot          0
# street            0
# city              0
# state             0
# zip_code          0
# house_size        0
# prev_sold_date    0
# dtype: int64

# %% [markdown]
# ## Checking Duplicates values

# %%
df.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2226377    False
# 2226378    False
# 2226379    False
# 2226380    False
# 2226381    False
# Length: 2226382, dtype: bool

# %% [markdown]
# ## Checking Duplicated sum values

# %%
df.duplicated().sum()
# Out:
# 32

# %% [markdown]
# ## Drop Duplicate values

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## All Duplicate values now drop

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking Outliers

# %%
for col in df.select_dtypes(include=np.number):
  sns.boxplot(x=df[col])
  plt.show()

# %% [markdown]
# ## Remove Outliers

# %%
quantile1=df['price'].quantile(0.25)
quantile3=df['price'].quantile(0.75)
iqr=quantile3-quantile1
upperl=quantile3+1.5*iqr
lowerl=quantile1-1.5*iqr
df['price']=df['price'].clip(upperl,lowerl)
upperl,lowerl
# Out:
# (1127500.0, -412500.0)

# %%
sns.boxplot(df['price'])
plt.show()

# %%
quantile1=df['bed'].quantile(0.25)
quantile3=df['bed'].quantile(0.75)
iqr=quantile3-quantile1
upperl=quantile3+1.5*iqr
lowerl=quantile1-1.5*iqr
df['bed']=df['bed'].clip(upperl,lowerl)
upperl,lowerl
# Out:
# (5.5, 1.5)

# %%
sns.boxplot(df['bed'])
plt.show()

# %%
quantile1=df['bath'].quantile(0.25)
quantile3=df['bath'].quantile(0.75)
iqr=quantile3-quantile1
upperl=quantile3+1.5*iqr
lowerl=quantile1-1.5*iqr
df['bath']=df['bath'].clip(upperl,lowerl)
upperl,lowerl
# Out:
# (4.5, 0.5)

# %%
sns.boxplot(df['bath'])
plt.show()

# %%
quantile1=df['acre_lot'].quantile(0.25)
quantile3=df['acre_lot'].quantile(0.75)
iqr=quantile3-quantile1
upperl=quantile3+1.5*iqr
lowerl=quantile1-1.5*iqr
df['acre_lot']=df['acre_lot'].clip(upperl,lowerl)
upperl,lowerl
# Out:
# (1.445, -0.595)

# %%
sns.boxplot(df['acre_lot'])
plt.show()

# %%
quantile1=df['house_size'].quantile(0.25)
quantile3=df['house_size'].quantile(0.75)
iqr=quantile3-quantile1
upperl=quantile3+1.5*iqr
lowerl=quantile1-1.5*iqr
df['house_size']=df['house_size'].clip(upperl,lowerl)
upperl,lowerl
# Out:
# (3550.0, -210.0)

# %%
sns.boxplot(df['house_size'])
plt.show()

# %% [markdown]
# ## Visualization Of Dataset using Histplot

# %%
for i in df.select_dtypes(include=np.number).columns:
    sns.histplot(df[i])
    plt.show()

# %% [markdown]
# The histplots show that several numerical features are skewed with visible outliers, indicating the need for data transformation and outlier treatment before modeling.

# %% [markdown]
# ## Checking distribution using distribution plot

# %%
for i in df.select_dtypes(include=np.number).columns:
  plt.title(i)
  sns.distplot(df[i],hist=False)
  plt.show()

# %% [markdown]
# ## Corelation using a Scatter Plot

# %%
for i in df.select_dtypes(include=np.number).columns:
    plt.title(i)
    plt.scatter(range(len(df[i])), df[i])
    plt.xlabel('Index')
    plt.ylabel(i)
    plt.show()

# %% [markdown]
# ## Checking Skewness using a KDE Plot

# %%
for i in df.select_dtypes(include=np.number).columns:
  plt.title(i)
  sns.distplot(df[i])
  plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
numeric_df = df.select_dtypes(include=['number'])

plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)

plt.title("Correlation Heatmap of U.S. Real Estate Features")
plt.show()
